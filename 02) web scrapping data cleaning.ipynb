# %% [markdown]
# # <u><h1 style="color: red;background-color: yellow;">1)Importing All Libraries We Require</h1><u><br></br>

# %%
import numpy as np
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

import matplotlib.pyplot as plt
import seaborn as sns

import time

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ### <h1 style="color: blue;background-color: white;">2)Importing csv file by using read_csv </h1><br></br>

# %%
df = pd.read_csv(r'C:\Users\HP\Data science with Python\main_df.csv')

# %%
df
# Out:
#      Unnamed: 0                       Title Year of Release Duration in min  \
# 0             0       \n1.\nThe Godfather\n         1972)\n         175 min
# 1             1          \n2.\nGoodfellas\n         1990)\n         146 min
# 2             2        \n3.\nPulp Fiction\n         1994)\n         154 min
# 3             3  \n4.\nThe Usual Suspects\n         1995)\n         106 min
# 4             4      \n5.\nApocalypse Now\n         1979)\n         147 min
# ..          ...                         ...             ...             ...
# 995         995          \n996.\nBlade II\n         2002)\n         117 min
# 996         996      \n997.\nFalling Down\n         1993)\n         113 min
# 997         997    \n998.\nEyes Wide Shut\n         1999)\n         159 min
# 998         998     \n999.\nThe Lost Boys\n         1987)\n          97 min
# 999         999      \n1,000.\nDeadpool 2\n         2018)\n         119 min
#
# ...

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">2)We are removing the Unnecessary items in the data frame</h1><u><br></br>

# %% [markdown]
# #### <u><h1 style="color: blue;background-color: white;">i)Data Cleaning</h1><u><br></br>

# %%
df['Genre'] = df['Genre'].apply(lambda x:x.replace('\n',''))

# %%
df['Duration in min'] = df['Duration in min'].apply(lambda x:x.replace('min',''))

# %%
df['Year of Release'] = df['Year of Release'].apply(lambda x:x.replace(')\n',''))

# %%
df['Title'] = df['Title'].apply(lambda x:x.replace('\n',''))

# %%
df['Votes in Views'] = df['Votes in Views'].apply(lambda x:x.replace(',',''))

# %%
df
# Out:
#      Unnamed: 0                 Title Year of Release Duration in min  \
# 0             0       1.The Godfather            1972            175
# 1             1          2.Goodfellas            1990            146
# 2             2        3.Pulp Fiction            1994            154
# 3             3  4.The Usual Suspects            1995            106
# 4             4      5.Apocalypse Now            1979            147
# ..          ...                   ...             ...             ...
# 995         995          996.Blade II            2002            117
# 996         996      997.Falling Down            1993            113
# 997         997    998.Eyes Wide Shut            1999            159
# 998         998     999.The Lost Boys            1987             97
# 999         999      1,000.Deadpool 2            2018            119
#
#                                      Genre  Rating Votes in Views  \
# 0                 Crime, Drama                 9.2         228221
# ...

# %% [markdown]
# #### <u><h1 style="color: blue;background-color: white;">ii)Checking that Nan values are present or not</h1><u><br></br>

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# Title                 0
# Year of Release       0
# Duration in min       0
# Genre                 0
# Rating                0
# Votes in Views        0
# Gross in Millions    60
# Action                0
# Horror                0
# Drama                 0
# Crime                 0
# Comedy                0
# Thriller              0
# Sci-Fi                0
# Mystery               0
# Adventure             0
# Biography             0
# war                   0
# dtype: int64

# %% [markdown]
# #### There are 60 nan values in the gross in millions columns

# %% [markdown]
# ---

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">iii)Checking the d-types of each column</h1><u><br></br>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1000 non-null   int64
#  1   Title              1000 non-null   object
#  2   Year of Release    1000 non-null   object
#  3   Duration in min    1000 non-null   object
#  4   Genre              1000 non-null   object
#  5   Rating             1000 non-null   float64
#  6   Votes in Views     1000 non-null   object
#  7   Gross in Millions  940 non-null    object
#  8   Action             1000 non-null   int64
#  9   Horror             1000 non-null   int64
#  10  Drama              1000 non-null   int64
#  11  Crime              1000 non-null   int64
#  12  Comedy             1000 non-null   int64
#  13  Thriller           1000 non-null   int64
#  14  Sci-Fi             1000 non-null   int64
#  15  Mystery            1000 non-null   int64
# ...

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">iv)Dropping the Nan Values</h1><u><br></br>

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Unnamed: 0                 Title Year of Release Duration in min  \
# 0             0       1.The Godfather            1972            175
# 1             1          2.Goodfellas            1990            146
# 2             2        3.Pulp Fiction            1994            154
# 3             3  4.The Usual Suspects            1995            106
# 4             4      5.Apocalypse Now            1979            147
# ..          ...                   ...             ...             ...
# 995         995          996.Blade II            2002            117
# 996         996      997.Falling Down            1993            113
# 997         997    998.Eyes Wide Shut            1999            159
# 998         998     999.The Lost Boys            1987             97
# 999         999      1,000.Deadpool 2            2018            119
#
#                                      Genre  Rating Votes in Views  \
# 0                 Crime, Drama                 9.2         228221
# ...

# %% [markdown]
# ###  Dropping the Unnamed column

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#                     Title Year of Release Duration in min  \
# 0         1.The Godfather            1972            175
# 1            2.Goodfellas            1990            146
# 2          3.Pulp Fiction            1994            154
# 3    4.The Usual Suspects            1995            106
# 4        5.Apocalypse Now            1979            147
# ..                    ...             ...             ...
# 995          996.Blade II            2002            117
# 996      997.Falling Down            1993            113
# 997    998.Eyes Wide Shut            1999            159
# 998     999.The Lost Boys            1987             97
# 999      1,000.Deadpool 2            2018            119
#
#                                      Genre  Rating Votes in Views  \
# 0                 Crime, Drama                 9.2         228221
# 1      Biography, Crime, Drama                 8.7         379413
# 2                 Crime, Drama                 8.9          83526
# ...

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">v)Removing the special characters in Gross in Millions column</h1><u><br></br>

# %%
df['Gross in Millions'] = df['Gross in Millions'].apply(lambda x:x.replace('$',''))

# %%
df['Gross in Millions'] = df['Gross in Millions'].apply(lambda x:x.replace('M',''))

# %%
df
# Out:
#                     Title Year of Release Duration in min  \
# 0         1.The Godfather            1972            175
# 1            2.Goodfellas            1990            146
# 2          3.Pulp Fiction            1994            154
# 3    4.The Usual Suspects            1995            106
# 4        5.Apocalypse Now            1979            147
# ..                    ...             ...             ...
# 995          996.Blade II            2002            117
# 996      997.Falling Down            1993            113
# 997    998.Eyes Wide Shut            1999            159
# 998     999.The Lost Boys            1987             97
# 999      1,000.Deadpool 2            2018            119
#
#                                      Genre  Rating Votes in Views  \
# 0                 Crime, Drama                 9.2         228221
# 1      Biography, Crime, Drama                 8.7         379413
# 2                 Crime, Drama                 8.9          83526
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">vi)Removing the numbers and pullstop which is present at Title</h1><u><br></br>

# %% [markdown]
# ## for that we are applying regex function

# %%
df['Title'][0]
# Out:
# '1.The Godfather'

# %%
import regex as re

p=re.compile(r"\.(.*)")

# %%
p.findall(df['Title'][0])
# Out:
# ['The Godfather']

# %%
d=df['Title'].apply(lambda x:p.findall(x))

# %%
d=d.apply(lambda x:"".join(x))

# %%
df['Title']=d

# %%
df
# Out:
#                   Title Year of Release Duration in min  \
# 0         The Godfather            1972            175
# 1            Goodfellas            1990            146
# 2          Pulp Fiction            1994            154
# 3    The Usual Suspects            1995            106
# 4        Apocalypse Now            1979            147
# ..                  ...             ...             ...
# 995            Blade II            2002            117
# 996        Falling Down            1993            113
# 997      Eyes Wide Shut            1999            159
# 998       The Lost Boys            1987             97
# 999          Deadpool 2            2018            119
#
#                                      Genre  Rating Votes in Views  \
# 0                 Crime, Drama                 9.2         228221
# 1      Biography, Crime, Drama                 8.7         379413
# 2                 Crime, Drama                 8.9          83526
# ...

# %% [markdown]
# # Again checking the d-types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 940 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              940 non-null    object
#  1   Year of Release    940 non-null    object
#  2   Duration in min    940 non-null    object
#  3   Genre              940 non-null    object
#  4   Rating             940 non-null    float64
#  5   Votes in Views     940 non-null    object
#  6   Gross in Millions  940 non-null    object
#  7   Action             940 non-null    int64
#  8   Horror             940 non-null    int64
#  9   Drama              940 non-null    int64
#  10  Crime              940 non-null    int64
#  11  Comedy             940 non-null    int64
#  12  Thriller           940 non-null    int64
#  13  Sci-Fi             940 non-null    int64
#  14  Mystery            940 non-null    int64
#  15  Adventure          940 non-null    int64
# ...

# %% [markdown]
# ### Here we have 'Duration in min','Votes in Views','Gross in Millions' in object, so we have to convert in int.

# %%
df['Duration in min']=df["Duration in min"].astype(int)

# %%
df['Votes in Views']=df['Votes in Views'].astype(int)

# %%
df['Gross in Millions']=df['Gross in Millions'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 940 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              940 non-null    object
#  1   Year of Release    940 non-null    object
#  2   Duration in min    940 non-null    int32
#  3   Genre              940 non-null    object
#  4   Rating             940 non-null    float64
#  5   Votes in Views     940 non-null    int32
#  6   Gross in Millions  940 non-null    float64
#  7   Action             940 non-null    int64
#  8   Horror             940 non-null    int64
#  9   Drama              940 non-null    int64
#  10  Crime              940 non-null    int64
#  11  Comedy             940 non-null    int64
#  12  Thriller           940 non-null    int64
#  13  Sci-Fi             940 non-null    int64
#  14  Mystery            940 non-null    int64
#  15  Adventure          940 non-null    int64
# ...

# %%
df
# Out:
#                   Title Year of Release  Duration in min  \
# 0         The Godfather            1972              175
# 1            Goodfellas            1990              146
# 2          Pulp Fiction            1994              154
# 3    The Usual Suspects            1995              106
# 4        Apocalypse Now            1979              147
# ..                  ...             ...              ...
# 995            Blade II            2002              117
# 996        Falling Down            1993              113
# 997      Eyes Wide Shut            1999              159
# 998       The Lost Boys            1987               97
# 999          Deadpool 2            2018              119
#
#                                      Genre  Rating  Votes in Views  \
# 0                 Crime, Drama                 9.2          228221
# 1      Biography, Crime, Drama                 8.7          379413
# 2                 Crime, Drama                 8.9           83526
# ...

# %% [markdown]
# # we have 940 rows but in data frame we have 999 in the last row. we will reset the index.

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index               Title Year of Release  Duration in min  \
# 0        0       The Godfather            1972              175
# 1        1          Goodfellas            1990              146
# 2        2        Pulp Fiction            1994              154
# 3        3  The Usual Suspects            1995              106
# 4        4      Apocalypse Now            1979              147
# ..     ...                 ...             ...              ...
# 935    995            Blade II            2002              117
# 936    996        Falling Down            1993              113
# 937    997      Eyes Wide Shut            1999              159
# 938    998       The Lost Boys            1987               97
# 939    999          Deadpool 2            2018              119
#
#                                      Genre  Rating  Votes in Views  \
# 0                 Crime, Drama                 9.2          228221
# ...

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                   Title Year of Release  Duration in min  \
# 0         The Godfather            1972              175
# 1            Goodfellas            1990              146
# 2          Pulp Fiction            1994              154
# 3    The Usual Suspects            1995              106
# 4        Apocalypse Now            1979              147
# ..                  ...             ...              ...
# 935            Blade II            2002              117
# 936        Falling Down            1993              113
# 937      Eyes Wide Shut            1999              159
# 938       The Lost Boys            1987               97
# 939          Deadpool 2            2018              119
#
#                                      Genre  Rating  Votes in Views  \
# 0                 Crime, Drama                 9.2          228221
# 1      Biography, Crime, Drama                 8.7          379413
# 2                 Crime, Drama                 8.9           83526
# ...

# %% [markdown]
# # Finally checking the Nan Values are present or not

# %%
df.isna().sum()
# Out:
# Title                0
# Year of Release      0
# Duration in min      0
# Genre                0
# Rating               0
# Votes in Views       0
# Gross in Millions    0
# Action               0
# Horror               0
# Drama                0
# Crime                0
# Comedy               0
# Thriller             0
# Sci-Fi               0
# Mystery              0
# Adventure            0
# Biography            0
# war                  0
# dtype: int64

# %%
df['Year of Release'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-e880fe9f00b1> in <module>
# ----> 1 df['Year of Release'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">vii)so there are some string values in year of release,we have to clean that too</h1><u><br></br>

# %%
df
# Out:
#                   Title Year of Release  Duration in min  \
# 0         The Godfather            1972              175
# 1            Goodfellas            1990              146
# 2          Pulp Fiction            1994              154
# 3    The Usual Suspects            1995              106
# 4        Apocalypse Now            1979              147
# ..                  ...             ...              ...
# 935            Blade II            2002              117
# 936        Falling Down            1993              113
# 937      Eyes Wide Shut            1999              159
# 938       The Lost Boys            1987               97
# 939          Deadpool 2            2018              119
#
#                                      Genre  Rating  Votes in Views  \
# 0                 Crime, Drama                 9.2          228221
# 1      Biography, Crime, Drama                 8.7          379413
# 2                 Crime, Drama                 8.9           83526
# ...

# %%
df['Year of Release']= df['Year of Release'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-cd53a6952d99> in <module>
# ----> 1 df['Year of Release']= df['Year of Release'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df = df[df['Year of Release']!='I) ']

# %%
df['Year of Release']= df['Year of Release'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-cd53a6952d99> in <module>
# ----> 1 df['Year of Release']= df['Year of Release'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df = df[df['Year of Release']!='500) Days of Summer\n']

# %%
df['Year of Release']= df['Year of Release'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-cd53a6952d99> in <module>
# ----> 1 df['Year of Release']= df['Year of Release'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df = df[df['Year of Release']!='1985–1998\nEpisode:\nThe Firm\n']

# %%
df['Year of Release']= df['Year of Release'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-cd53a6952d99> in <module>
# ----> 1 df['Year of Release']= df['Year of Release'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df = df[df['Year of Release']!='II) ']

# %%
df['Year of Release']= df['Year of Release'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-cd53a6952d99> in <module>
# ----> 1 df['Year of Release']= df['Year of Release'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df = df[df['Year of Release']!='The Unexpected Virtue of Ignorance']

# %%
df['Year of Release']= df['Year of Release'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-cd53a6952d99> in <module>
# ----> 1 df['Year of Release']= df['Year of Release'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df = df[df['Year of Release']!='III) ']

# %% [markdown]
# ## we have removed each and every special character and unknown values in year of release column.

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">viii)Converting Year of Release column into int </h1><u><br></br>

# %%
df['Year of Release']= df['Year of Release'].astype(int)

# %%
df.info()

# finally we converted the year of release column into int d-type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 906 entries, 0 to 939
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              906 non-null    object
#  1   Year of Release    906 non-null    int32
#  2   Duration in min    906 non-null    int32
#  3   Genre              906 non-null    object
#  4   Rating             906 non-null    float64
#  5   Votes in Views     906 non-null    int32
#  6   Gross in Millions  906 non-null    float64
#  7   Action             906 non-null    int64
#  8   Horror             906 non-null    int64
#  9   Drama              906 non-null    int64
#  10  Crime              906 non-null    int64
#  11  Comedy             906 non-null    int64
#  12  Thriller           906 non-null    int64
#  13  Sci-Fi             906 non-null    int64
#  14  Mystery            906 non-null    int64
#  15  Adventure          906 non-null    int64
# ...

# %%
df
# Out:
#                   Title  Year of Release  Duration in min  \
# 0         The Godfather             1972              175
# 1            Goodfellas             1990              146
# 2          Pulp Fiction             1994              154
# 3    The Usual Suspects             1995              106
# 4        Apocalypse Now             1979              147
# ..                  ...              ...              ...
# 935            Blade II             2002              117
# 936        Falling Down             1993              113
# 937      Eyes Wide Shut             1999              159
# 938       The Lost Boys             1987               97
# 939          Deadpool 2             2018              119
#
#                                      Genre  Rating  Votes in Views  \
# 0                 Crime, Drama                 9.2          228221
# 1      Biography, Crime, Drama                 8.7          379413
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index               Title  Year of Release  Duration in min  \
# 0        0       The Godfather             1972              175
# 1        1          Goodfellas             1990              146
# 2        2        Pulp Fiction             1994              154
# 3        3  The Usual Suspects             1995              106
# 4        4      Apocalypse Now             1979              147
# ..     ...                 ...              ...              ...
# 901    935            Blade II             2002              117
# 902    936        Falling Down             1993              113
# 903    937      Eyes Wide Shut             1999              159
# 904    938       The Lost Boys             1987               97
# 905    939          Deadpool 2             2018              119
#
#                                      Genre  Rating  Votes in Views  \
# 0                 Crime, Drama                 9.2          228221
# ...

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                   Title  Year of Release  Duration in min  \
# 0         The Godfather             1972              175
# 1            Goodfellas             1990              146
# 2          Pulp Fiction             1994              154
# 3    The Usual Suspects             1995              106
# 4        Apocalypse Now             1979              147
# ..                  ...              ...              ...
# 901            Blade II             2002              117
# 902        Falling Down             1993              113
# 903      Eyes Wide Shut             1999              159
# 904       The Lost Boys             1987               97
# 905          Deadpool 2             2018              119
#
#                                      Genre  Rating  Votes in Views  \
# 0                 Crime, Drama                 9.2          228221
# 1      Biography, Crime, Drama                 8.7          379413
# ...

# %% [markdown]
# ### <u><h1 style="color: blue;background-color: white;">3)Finally we have done cleaning and saving it into csv</h1><u><br></br>

# %%
df.to_csv(r'C:\Users\HP\Data science with Python\02) web scrapping\cleaned_df.csv')
